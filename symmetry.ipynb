# %% [markdown]
# from pymatgen.ext.matproj import MPRester
# from pymatgen.io.cif import CifParser
# from pymatgen.symmetry.analyzer import SpacegroupAnalyzer
# from IPython.display import Image
# with MPRester("z18b57ZwfPDtXJVD") as me :
#
#     #

# %%
from pymatgen.ext.matproj import MPRester 
from pymatgen.io.cif import CifParser 
from pymatgen.symmetry.analyzer import SpacegroupAnalyzer 
from IPython.display import Image 
from pymatgen.core.operations import SymmOp
with MPRester("z18b57ZwfPDtXJVD") as m :

    # Structure for material id : 
    structure = m.get_structure_by_material_id("mp-755544")
    print("Structure de la molecule")
    print(structure, '\n')
    
    # Symétrie 1 - réflexion par rapport à un plan mirroir
    sym1 = SymmOp.from_xyz_string('-y,-x,z')
    sym1_op = sym1.operate([0.00, 0.00, 0.50])
    Im1 = Image(filename = 'sym1.jpg')
    
    # Symétrie 2 - roto-inversion d'ordre 3
    sym2 = SymmOp.from_xyz_string('x-y,x,-z')
    sym2_op = sym1.operate([0.00, 0.00, 0.22])
    Im2 = Image(filename = 'sym2.jpg')
    
    # Symétrie 3 - rotation de 180°
    sym3 = SymmOp.from_xyz_string('y,x,-z')
    sym3_op = sym1.operate([0.67, 0.33, 0.83])
    Im3 = Image(filename = 'sym3.jpg')
# Out:
# Structure de la molecule
# Full Formula (Y1 Tl1 O2)
# Reduced Formula: YTlO2
# abc   :   3.512462   6.809539   3.512462
# angles: 104.945941  59.999995 104.945939
# Sites (4)
#   #  SP           a        b         c    magmom
# ---  ----  --------  -------  --------  --------
#   0  Y     0.5       0.5      0.5              0
#   1  Tl    0         0        0                0
#   2  O     0.224316  0.67295  0.224316         0
#   3  O     0.775684  0.32705  0.775684         0

# %%
print("Symetrie 1 : réflexion par rapport à un plan mirroir" + '\n' + "Cet opérateur de symétrie est un plan miroir perpendiculaire à la direction [-1, -1, 0] passant par le point (0.00, 0.00, 0.50) . Les éléments situés en (x,y,z) ont un équivalent en (-y,-x,z). La matrice associé est  : ")
print(sym1.rotation_matrix)
print("L'opération de symétrie appliquée à l'atome Y situé en (0.00, 0.00, 0.50) renvoie l'atome Y situé en ")
print(sym1_op)
display (Im1)
# Out:
# Symetrie 1 : réflexion par rapport à un plan mirroir
# Cet opérateur de symétrie est un plan miroir perpendiculaire à la direction [-1, -1, 0] passant par le point (0.00, 0.00, 0.50) . Les éléments situés en (x,y,z) ont un équivalent en (-y,-x,z). La matrice associé est  :
# [[ 0. -1.  0.]
#  [-1.  0.  0.]
#  [ 0.  0.  1.]]
# L'opération de symétrie appliquée à l'atome Y situé en (0.00, 0.00, 0.50) renvoie l'atome Y situé en
# [0.  0.  0.5]

# %%
print("Symetrie 2 : roto-inversion d'ordre 3" + '\n' + "Cet opérateur de symétrie est un roto-inversion d'ordre 3 et de centre d'inversion (0.00,0.00,0.00). Les éléments situés en (x,y,z) ont un équivalent en (x-y,x,-z). La matrice associé est  : ")
print(sym2.rotation_matrix)
print("L'opération de symétrie appliquée à l'atome O situé en (0.00, 0.00, 0.22) renvoie l'atome O situé en ")
print(sym2_op)
display (Im2)
# Out:
# Symetrie 2 : roto-inversion d'ordre 3
# Cet opérateur de symétrie est un roto-inversion d'ordre 3 et de centre d'inversion (0.00,0.00,0.00). Les éléments situés en (x,y,z) ont un équivalent en (x-y,x,-z). La matrice associé est  :
# [[ 1. -1.  0.]
#  [ 1.  0.  0.]
#  [ 0.  0. -1.]]
# L'opération de symétrie appliquée à l'atome O situé en (0.00, 0.00, 0.22) renvoie l'atome O situé en
# [0.   0.   0.22]

# %%
print("Symetrie 3 : rotation d'ordre 2" + '\n' + "Cet opérateur de symétrie est un rotation d'ordre 2 autour de l'axe  (1.00, 1.00, -1.00). Les éléments situés en (x,y,z) ont un équivalent en (y,x,-z). La matrice associé est  : ")
print(sym3.rotation_matrix)
print("L'opération de symétrie appliquée à l'atome Y situé en (0.67, 0.33, 0.83) renvoie l'atome Y situé en ")
print(sym3_op)
display (Im3)
# Out:
# Symetrie 3 : rotation d'ordre 2
# Cet opérateur de symétrie est un rotation d'ordre 2 autour de l'axe  (1.00, 1.00, -1.00). Les éléments situés en (x,y,z) ont un équivalent en (y,x,-z). La matrice associé est  :
# [[ 0.  1.  0.]
#  [ 1.  0.  0.]
#  [ 0.  0. -1.]]
# L'opération de symétrie appliquée à l'atome Y situé en (0.67, 0.33, 0.83) renvoie l'atome Y situé en
# [-0.33 -0.67  0.83]
